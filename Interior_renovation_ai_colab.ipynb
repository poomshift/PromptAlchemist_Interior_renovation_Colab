# %% [markdown]
# <a href="https://colab.research.google.com/github/poomshift/PromptAlchemist_Interior_renovation_Colab/blob/main/Interior_renovation_ai_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Untitlead-2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ***Interior Renovation Ai | รีโนเวทห้องด้วย Ai***
#
# เป็นโปรเจคที่ผมทำขึ้นเพื่อเรียนรู้การสร้างโปรแกรมสำหรับเจนภาพด้วยตัวเอง
#
# ติดตามอัพเดทเกี่ยวกับเทคโนโลยี Ai ที่ [Facebook/promptalchemist](https://facebook.com/PromptAlchemist)
#
# Google Colab สำหรับ Stable Diffusion WebUI [>>คลิก<<](https://colab.research.google.com/github/poomshift/PromptAlchemist_SD_Webui_Colab/blob/main/PromptAlchemist_SD_Webui_Colab.ipynb#scrollTo=1F-zYI2-Uo0a)

# %%
#@markdown # 1. ติดตั้ง Dependencies ก่อน
from IPython.display import clear_output
from IPython.display import Javascript
import ipywidgets as widgets
display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 200})'''))
def inf(msg, style, wdth): inf = widgets.Button(description=msg, disabled=True, button_style=style, layout=widgets.Layout(min_width=wdth));display(inf)

# !git clone https://github.com/poomshift/PromptAlchemist_Interior_renovation_Colab
# !pip install transformers diffusers numpy torch accelerate gradio
# !wget https://huggingface.co/cyberdelia/CyberRealistic/resolve/main/CyberRealistic_V4.1_FP16.safetensors

clear_output()
inf('\u2714 Done','success', '50px')

# %%
#@markdown # 2. Run โปรแกรม
from IPython.display import Javascript
display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 200})'''))
# !python /content/PromptAlchemist_Interior_renovation_Colab/app.py
